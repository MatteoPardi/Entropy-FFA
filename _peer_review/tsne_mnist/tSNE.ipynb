# %% [markdown]
# # tSNE

# %%
import sys
sys.path.insert(1, '../../_tools/')
import torch as th
import numpy as np
import torchvision
import torchvision.transforms as trasf
import matplotlib.pyplot as plt

seed = 42
th.manual_seed(seed)
np.random.seed(seed)
device = th.device('cpu')

# %% [markdown]
# ### Data

# %%
TS_torch_dataset = torchvision.datasets.MNIST(
    root=r"C:\Users\matte\LocalData\Master Thesis",
    train=False,
    download=True,
    transform=trasf.ToTensor()
)

# Load everything
TSx = th.stack([x.flatten() for x, y in TS_torch_dataset]).to(device)
TSy = th.tensor([y for x, y in TS_torch_dataset], device=device)
TSy = TSy.numpy()

# %% [markdown]
# ### Models

# %%
base_path = "../../mnist experiment/final models/"

models = {
    'T off 20': None,
    'T on 20': None,
    'T off 200': None,
    'T on 200': None,
    'T off 2000': None,
    'T on 2000': None
}

for exp in models:
    models[exp] = th.load(base_path+exp+'.pt', device)

# %% [markdown]
# ***

# %%
from sklearn.manifold import TSNE
import pickle

exps_x2D = {}

for exp, model in models.items():
    print(exp)
    tsne = TSNE(learning_rate='auto', init='pca', n_iter=1000, verbose=1)
    sum_norm_godness = model.sum_normalized_goodness(TSx)
    exps_x2D[exp] = tsne.fit_transform(sum_norm_godness)

with open("exps_x2D.pickle", 'wb') as f:
    pickle.dump(exps_x2D, f)
# Out:
# T off 20
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.000s...
# [t-SNE] Computed neighbors for 10000 samples in 0.761s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.014816
# C:\Users\matte\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.270409
# [t-SNE] KL divergence after 1000 iterations: 1.688087
# T on 20
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.016s...
# [t-SNE] Computed neighbors for 10000 samples in 1.624s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.006162
# C:\Users\matte\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.104637
# [t-SNE] KL divergence after 1000 iterations: 1.686775
# T off 200
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.000s...
# [t-SNE] Computed neighbors for 10000 samples in 1.477s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.020169
# C:\Users\matte\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.578323
# [t-SNE] KL divergence after 1000 iterations: 1.827210
# T on 200
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.009s...
# [t-SNE] Computed neighbors for 10000 samples in 1.486s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.008685
# C:\Users\matte\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.413208
# [t-SNE] KL divergence after 1000 iterations: 1.673061
# T off 2000
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.016s...
# [t-SNE] Computed neighbors for 10000 samples in 1.335s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.035768
# C:\Users\matte\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.261215
# [t-SNE] KL divergence after 1000 iterations: 1.573356
# T on 2000
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.007s...
# [t-SNE] Computed neighbors for 10000 samples in 0.960s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.009701
# C:\Users\matte\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.958145
# [t-SNE] KL divergence after 1000 iterations: 1.242174

# %% [markdown]
# ***

# %%
with open("exps_x2D.pickle", 'rb') as f:
    exps_x2D = pickle.load(f)

labels = list(range(0, 10))
colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple']
names = [str(label) for label in labels]

for exp, x2D in exps_x2D.items():
    
    plt.figure()
    plt.title(exp)
    for label, color, name in zip(labels, colors, names):
        x = x2D[TSy==label]
        plt.scatter(x[:, 0], x[:, 1], color=color, label=name)
    plt.legend(loc='best')
